# %%
import sys
sys.path.append("..")
from app.main import run_example

# %%
run_example()
# Out:
# 2026-01-09 04:52:22 - INFO - Starting ETL.Orchestrator.run...
# /home/jovyan/work
# 2026-01-09 04:52:22 - INFO - Extracting data from app/src/data/test.csv...
# /home/jovyan/work
# 2026-01-09 04:52:22 - INFO - Extracted naive plan: (run LazyFrame.explain(optimized=True) to see the optimized plan)
#
# SELECT [col("id").count(), col("name").count(), col("address").count(), col("color").count(), col("created_at").count(), col("last_login").count(), col("is_claimed").count(), col("paid_amount").count()]
#   Csv SCAN [app/src/data/test.csv]
#   PROJECT */8 COLUMNS
#   ESTIMATED ROWS: 4011689 records
# 2026-01-09 04:52:22 - INFO - Transforming data in bathces...
# 2026-01-09 04:53:26 - INFO - Loading data to database...
# 2026-01-09 04:53:51 - INFO - Successfully wrote data to table 'tests'
# 2026-01-09 04:53:51 - INFO - ETL process completed successfully!
# 2026-01-09 04:54:53 - INFO - Loading data to database...
# 2026-01-09 04:55:12 - INFO - Successfully wrote data to table 'tests'
# ...
