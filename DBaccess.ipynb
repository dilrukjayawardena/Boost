# %%
# %load_ext sql
# %sql mysql+pymysql://app_user:app_password@mysql/app_db
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# SELECT * FROM users LIMIT 10;
# Out:
#  * mysql+pymysql://app_user:***@mysql/app_db
# 10 rows affected.
# [('e9703a66-6556-4b48-8a0b-0ace129d7a11', 'Joshua Webster', datetime.date(1983, 5, 15), '208 Ewing Pine\nNorth Dana, MN 35292', 'bboyle@garza-shelton.net', 'gAAAAABpYG1_obtIIQu-E0-RxPoNIviWlaPkrtksG525-Qr1k8Hbk0AbgEDQwtINWDbA_BflGNRs69y03LeDJKggNtSqs_rAyg==', 'gAAAAABpYG1_FpFbqDZHifHrL0HIOS7OlCG4LwKTcYzkdnwacM5AiV3Y_9wInatfRVP-MBdp_ca79-0pEKOKgnOAUZ1jE01NWg==', datetime.datetime(2026, 1, 9, 2, 52, 48), datetime.datetime(2026, 1, 9, 2, 52, 48), datetime.datetime(1997, 12, 12, 0, 3, 28)),
# ...

# %%
# %%sql
# SELECT * FROM jobs_history LIMIT 10;
# Out:
#  * mysql+pymysql://app_user:***@mysql/app_db
# 10 rows affected.
# [('e9703a66-6556-4b48-8a0b-0ace129d7a11', 'Set designer', 0, datetime.date(1996, 12, 26), datetime.date(1997, 10, 2)),
#  ('aa246388-104c-44f7-93f4-4b688dc0baff', 'Chief of Staff', 1, datetime.date(1991, 9, 12), datetime.date(2015, 8, 4)),
#  ('86af3e4d-6c57-4245-be99-19b2bfb138c0', 'Clinical cytogeneticist', 1, datetime.date(1970, 10, 28), datetime.date(2018, 3, 30)),
#  ('a610bdb4-8d67-47b0-b6f6-791a8ea22d86', 'Manufacturing systems engineer', 1, datetime.date(2007, 5, 5), datetime.date(2014, 7, 1)),
#  ('2bde2981-4bd8-4da0-ab3b-9ff26a4cebd8', 'Counselling psychologist', 0, datetime.date(1989, 12, 24), None),
#  ('2bde2981-4bd8-4da0-ab3b-9ff26a4cebd8', 'Social research officer, government', None, datetime.date(2014, 1, 29), datetime.date(1973, 9, 19)),
#  ('c9b28796-0bef-429f-ae2f-ca75511ead9e', 'Cabin crew', 1, datetime.date(2019, 12, 21), datetime.date(1986, 3, 31)),
# ...

# %%
# %%sql
# SELECT * FROM telephone_numbers LIMIT 10;
# Out:
#  * mysql+pymysql://app_user:***@mysql/app_db
# 10 rows affected.
# [(1, 'e9703a66-6556-4b48-8a0b-0ace129d7a11', '001-640-924-3637x268'),
#  (2, 'e9703a66-6556-4b48-8a0b-0ace129d7a11', '001-127-583-8338x85397'),
#  (3, 'aa246388-104c-44f7-93f4-4b688dc0baff', '840.808.9845'),
#  (4, 'aa246388-104c-44f7-93f4-4b688dc0baff', '001-558-896-0120x701'),
#  (5, '86af3e4d-6c57-4245-be99-19b2bfb138c0', '001-672-539-5662x6286'),
#  (6, '86af3e4d-6c57-4245-be99-19b2bfb138c0', '310-693-9384'),
#  (7, 'a610bdb4-8d67-47b0-b6f6-791a8ea22d86', '+1-098-016-5290x70377'),
#  (8, 'a610bdb4-8d67-47b0-b6f6-791a8ea22d86', '+1-348-828-2586x800'),
#  (9, '2bde2981-4bd8-4da0-ab3b-9ff26a4cebd8', '(168)847-2979x521'),
#  (10, '2bde2981-4bd8-4da0-ab3b-9ff26a4cebd8', '(975)922-1242x44183')]

# %%
# %%sql
# show tables;
# Out:
#  * mysql+pymysql://app_user:***@mysql/app_db
# 4 rows affected.
# [('telephone_numbers',), ('tests',), ('users',), ('users_tb',)]

# %%
# %%sql
# Delete from telephone_numbers;
# Delete from jobs_history;
# Delete from users;
# Out:
#  * mysql+pymysql://app_user:***@mysql/app_db
# 266577 rows affected.
# 133307 rows affected.
# 100000 rows affected.
# []

# %%
# %%sql
#
# describe tests;
# Out:
#  * mysql+pymysql://app_user:***@mysql/app_db
# 9 rows affected.
# [('id_key', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('id', 'int', 'YES', '', None, ''),
#  ('name', 'varchar(100)', 'YES', '', None, ''),
#  ('address', 'varchar(200)', 'YES', '', None, ''),
#  ('color', 'varchar(50)', 'YES', '', None, ''),
#  ('created_at', 'timestamp', 'YES', '', None, ''),
#  ('last_login', 'timestamp', 'YES', '', 'CURRENT_TIMESTAMP', 'DEFAULT_GENERATED'),
#  ('is_claimed', 'tinyint(1)', 'YES', '', None, ''),
#  ('paid_amount', 'decimal(10,0)', 'YES', '', None, '')]
